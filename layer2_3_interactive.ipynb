# %% [markdown]
# <a href="https://colab.research.google.com/github/sahardan-lab/layer2-3-interactiv/blob/main/layer2_3_interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
from IPython.display import display, HTML
import time

# 1. הגדרת ה-API Key
genai.configure(api_key="AIzaSyBYVphkLZGMQoZdbSsdeRhU2rg6yfL2Ffk")
model = genai.GenerativeModel('gemini-1.5-flash')

# 2. פונקציה ליצירת מד התקדמות (Progress Bar)
def show_progress(percent, stage_name):
    html = f"""
    <div style="direction: rtl; text-align: right; font-family: 'Arial'; margin: 10px 0;">
        <span style="font-size: 14px; font-weight: bold; color: #5f6368;">התקדמות ב-OSI Stack: {stage_name}</span>
        <div style="background-color: #e0e0e0; border-radius: 10px; width: 100%; height: 20px; margin-top: 5px;">
            <div style="background-color: #34a853; width: {percent}%; height: 100%; border-radius: 10px; transition: width 0.5s;"></div>
        </div>
    </div>
    """
    display(HTML(html))

# 3. פונקציית תצוגת השלבים
def show_stage(title, description, visual_art, color="#4285f4"):
    html = f"""
    <div style="direction: rtl; text-align: right; font-family: 'Segoe UI'; margin: 15px 0; animation: fadeIn 1s;">
        <div style="background-color: {color}; color: white; padding: 12px; border-radius: 15px 15px 0 0; font-weight: bold; font-size: 18px;">
            🚀 {title}
        </div>
        <div style="border: 3px solid {color}; padding: 20px; border-radius: 0 0 15px 15px; background-color: #ffffff; box-shadow: 0 4px 6px rgba(0,0,0,0.1);">
            <p style="font-size: 16px; color: #3c4043;">{description}</p>
            <div style="background: #2d2e31; color: #00ff41; padding: 15px; border-radius: 8px; font-family: 'Courier New', monospace; font-size: 14px; overflow-x: auto;">
                <pre style="margin: 0;">{visual_art}</pre>
            </div>
        </div>
    </div>
    """
    display(HTML(html))

def show_chat(text, role='bot'):
    bg = "#e8f0fe" if role == 'bot' else "#f1f3f4"
    label = "🤖 NetCoach" if role == 'bot' else "👤 אתה"
    html = f'<div style="direction: rtl; text-align: right; margin: 8px;"><b style="font-size: 12px; color: #70757a;">{label}</b><br><div style="background:{bg}; padding:12px; border-radius:15px; display:inline-block; max-width:85%; box-shadow: 1px 1px 2px rgba(0,0,0,0.1);">{text}</div></div>'
    display(HTML(html))

# 4. הרצת הסימולציה
system_context = "אתה NetCoach, מורה מלהיב. שמור על תשובות קצרות. הסבר את ה-NIC והשכבות לפי האינפוגרפיקות."
chat = model.start_chat(history=[])

show_chat("אחונמיאנסקי! ברוך הבא לסימולציה האינטראקטיבית. אנחנו עומדים לשגר פאקט (Packet) דרך הרשת. מוכן? כתוב 'שגר!'", 'bot')

user_start = input("הקלד כאן: ")
show_chat(user_start, 'user')

# שלב 1: שכבה 3 - האריזה מתחילה
show_progress(33, "שכבה 3 - Network")
show_stage("שכבת הרשת: יצירת ה-Packet",
           "הודעת ה-'Hello' שלך נארזת בתוך IP Packet. נוספה כתובת ה-IP של היעד.",
           "  [ IP SRC: 192.168.1.10 ]\n  [ IP DST: 192.168.1.1  ]\n  [ DATA: 'Hello'      ]")

# שלב 2: ה-NIC הופך ל-Master של שכבה 2
show_chat("עכשיו ה-NIC (כרטיס הרשת) לוקח את החבילה. הוא עוטף אותה ב-Frame. מה הוא מוסיף כדי שהסוויץ' ידע לאן לשלוח?", 'bot')
ans = input("תשובה (א-MAC, ב-IP, ג-סיבים): ")
show_chat(ans, 'user')

show_progress(66, "שכבה 2 - Data Link")
show_stage("ה-NIC מבצע Encapsulation",
           "ה-NIC מוסיף MAC Address (כתובת פיזית) ובדיקת תקינות (FCS). כעת זו 'מסגרת' (Frame).",
           "  ┌──────────────────────────────────┐\n  │ MAC Dest | MAC Source | IP Pkt | FCS │\n  └──────────────────────────────────┘\n        ^ NIC JUST ADDED THIS! ^")

# שלב 3: השכבה הפיזית - הפיכה לאותות
show_chat("ה-NIC הופך את ה-Frame לזרם של ביטים ומשגר אותם כפולסים חשמליים בכבל נחושת!", 'bot')
show_progress(100, "שכבה 1 - Physical")
show_stage("השכבה הפיזית: שידור סיגנלים",
           "הביטים הופכים למתח חשמלי שנע במהירות האור לעבר היעד.",
           "  Bits: 01011001 01101011\n  Signals: _/‾\_/‾\_/‾\_/‾\_/‾\n  Media: [==== Copper Cable ====] ⚡⚡⚡")

show_chat("מדהים! ההודעה עברה De-encapsulation בצד השני והגיעה ליעד. קיבלת 100 בפרויקט!", 'bot')
# שלב 4: הצד המקבל - מהפיזי חזרה ללוגי
show_chat("האותות הגיעו ל-NIC של המקבל! עכשיו קורה הקסם ההפוך: De-encapsulation.", 'bot')
show_progress(66, "צד מקבל: שכבה 2 (Data Link)")

# שאלה קריטית על הצד המקבל
show_chat("ה-NIC המקבל מסתכל על ה-Frame. מה הדבר הראשון שהוא בודק כדי לדעת אם ההודעה בכלל מיועדת אליו?", 'bot')
ans_rec = input("תשובה (א-IP, ב-MAC, ג-סיסמה): ")
show_chat(ans_rec, 'user')

show_stage("ה-NIC המקבל: קילוף ה-Frame",
           "ה-NIC מוודא שכתובת ה-MAC תואמת לשלו ובודק את ה-FCS (תקינות). אם הכל תקין, הוא 'מקלף' את ה-Header וה-Trailer.",
           "  [ MAC Dest Check: OK! ]\n  [ FCS Check: Valid ✔️ ]\n  --> Peeling off Layer 2 Header...")



# שלב 5: חזרה לשכבה 3 (ההודעה המקורית)
show_progress(33, "צד מקבל: שכבה 3 (Network)")
show_stage("שכבת הרשת במקבל",
           "ה-NIC העביר את ה-Packet למערכת ההפעלה. עכשיו המחשב המקבל רואה את ה-IP ומחלץ את המידע.",
           "  [ IP Packet Received ]\n  [ Extracting Data... ]\n  [ DATA: 'Hello' ]")

# שלב 6: סיום חגיגי
show_progress(0, "הודעה התקבלה!")
show_chat("אחונמיאנסקי, הצלחנו! ההודעה עברה את כל הדרך. מצד שולח לצד מקבל. זה פרויקט של 100 עגול!", 'bot')

print_rtl("--- סוף הסימולציה האינטראקטיבית ---")
# Out:
# <div style="direction: rtl; text-align: right; margin: 8px;"><b style="font-size: 12px; color: #70757a;">🤖 NetCoach</b><br><div style="background:#e8f0fe; padding:12px; border-radius:15px; display:inline-block; max-width:85%; box-shadow: 1px 1px 2px rgba(0,0,0,0.1);">אחונמיאנסקי! ברוך הבא לסימולציה האינטראקטיבית. אנחנו עומדים לשגר פאקט (Packet) דרך הרשת. מוכן? כתוב 'שגר!'</div></div>
# הקלד כאן: שגר
# <div style="direction: rtl; text-align: right; margin: 8px;"><b style="font-size: 12px; color: #70757a;">👤 אתה</b><br><div style="background:#f1f3f4; padding:12px; border-radius:15px; display:inline-block; max-width:85%; box-shadow: 1px 1px 2px rgba(0,0,0,0.1);">שגר</div></div>
#     <div style="direction: rtl; text-align: right; font-family: 'Arial'; margin: 10px 0;">
#         <span style="font-size: 14px; font-weight: bold; color: #5f6368;">התקדמות ב-OSI Stack: שכבה 3 - Network</span>
# ...
